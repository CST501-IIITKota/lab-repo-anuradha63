# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/linear-regression-salary-dataset/__results__.html
# /kaggle/input/linear-regression-salary-dataset/__resultx__.html
# /kaggle/input/linear-regression-salary-dataset/__notebook__.ipynb
# /kaggle/input/linear-regression-salary-dataset/__output__.json
# /kaggle/input/linear-regression-salary-dataset/custom.css
# /kaggle/input/linear-regression-salary-dataset/__results___files/__results___67_0.png
# /kaggle/input/linear-regression-salary-dataset/__results___files/__results___24_0.png
# /kaggle/input/linear-regression-salary-dataset/__results___files/__results___69_0.png
# /kaggle/input/linear-regression-salary-dataset/__results___files/__results___27_0.png
# /kaggle/input/linear-regression-salary-dataset/__results___files/__results___71_0.png
# /kaggle/input/linear-regression-salary-dataset/__results___files/__results___30_0.png
# /kaggle/input/linear-regression-salary-dataset/__results___files/__results___23_0.png
# /kaggle/input/linear-regression-salary-dataset/__results___files/__results___32_0.png
# /kaggle/input/linear-regression-salary-dataset/__results___files/__results___73_0.png
# /kaggle/input/linear-regression-salary-dataset/__results___files/__results___75_0.png
# /kaggle/input/linear-regression-salary-dataset/__results___files/__results___28_0.png

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/kaggle/input/salary-dataset/Salary_dataset.csv")

# %%
data
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# 21          21              7.2   98274.0
# 22          22              8.0  101303.0
# 23          23              8.3  113813.0
# 24          24              8.8  109432.0
# 25          25              9.1  105583.0
# 26          26              9.6  116970.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0
# 29          29             10.6  121873.0

# %%
data = data.drop(columns=["Unnamed: 0"], errors="ignore")

# %%
data
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.413333   76004.000000
# std           2.837888   27414.429785
# min           1.200000   37732.000000
# 25%           3.300000   56721.750000
# 50%           4.800000   65238.000000
# 75%           7.800000  100545.750000
# max          10.600000  122392.000000

# %%
plt.scatter(data['YearsExperience'],data['Salary'])

# %%
x = data[["YearsExperience"]]
y = data["Salary"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
# 28    10.4
# 24     8.8
# 12     4.1
# 0      1.2
# 4      2.3
# 16     5.2
# 5      3.0
# 13     4.2
# 11     4.1
# 22     8.0
# 1      1.4
# 2      1.6
# 25     9.1
# 3      2.1
# 21     7.2
# 26     9.6
# 18     6.0
# 29    10.6
# 20     6.9
# 7      3.3
# 10     4.0
# 14     4.6
# 19     6.1
# 6      3.1
# Name: YearsExperience, dtype: float64

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
print("Intercept:", model.intercept_)
print("Slope:", model.coef_)
# Out:
# Intercept: 24380.201479473704
# Slope: [9423.81532303]

# %%
plt.scatter(x, y)
plt.plot(x, model.predict(x))
plt.xlabel("Experience (Years)")
plt.ylabel("Salary (₹ Lakhs)")
plt.title("Linear Regression - Salary Prediction")
plt.show()
